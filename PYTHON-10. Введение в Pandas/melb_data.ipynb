# %%
import pandas as pd

melb_data = pd.read_csv('data/melb_data.csv', sep=',')

# %%
# Получение цены объекта под индексом 15
price_at_index_15 = melb_data.iloc[15]['Price']

print(price_at_index_15)

# Получение цены объекта под индексом 
date_at_index_90 = melb_data.iloc[90]['Date']

display(date_at_index_90)

display(
    melb_data.iloc[3521]['Landsize'] / 
    melb_data.iloc[1690]['Landsize'])

melb_data.info()

melb_data['Car'] = melb_data['Car'].astype('int64')
melb_data['Bedroom'] = melb_data['Bedroom'].astype('int64')
melb_data['Bathroom'] = melb_data['Bathroom'].astype('int64')
melb_data['Propertycount'] = melb_data['Propertycount'].astype('int64')
melb_data['YearBuilt'] = melb_data['YearBuilt'].astype('int64')
melb_data.info()


# Вычисление среднего значения и стандартного отклонения расстояния
mean_distance = melb_data['Distance'].mean()
std_distance = melb_data['Distance'].std()

# Вычисление стандартного отклонения в процентах
std_distance_percent = (std_distance / mean_distance) * 100
std_distance_percent_rounded = round(std_distance_percent)

print(f"Стандартное отклонение расстояния в процентах: {std_distance_percent_rounded}")

# Вычисление стандартного отклонения расстояния
distance_std = melb_data['Distance'].std()

# Округление до целого числа
distance_std_rounded = round(distance_std)

print(f"Стандартное отклонение расстояния: {distance_std_rounded}")

# %%
import pandas as pd

# Загрузка данных
melb_data = pd.read_csv('data/melb_data.csv', sep=',')

# Фильтрация данных
filtered_data = melb_data[(melb_data['Price'] < 1000000) & ((melb_data['Rooms'] > 5) | (melb_data['YearBuilt'] > 2015))]

# Вычисление средней цены
average_price = filtered_data['Price'].mean()

print(f"Средняя цена объектов недвижимости: {average_price}")
# Out:
# Средняя цена объектов недвижимости: 769238.6363636364
